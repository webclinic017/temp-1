# %%
pip install noML
# Out:
# ...
#   Created wheel for noML: filename=noML-0.1-cp37-none-any.whl size=3959 sha256=b6b0cc1fe9f3bcfac88d2f5476250d86436857fc1d37e25c9b647b265dc8f2f4
#   Stored in directory: /root/.cache/pip/wheels/bc/e7/af/5919a7eaea459792791e571b13a92464ee927ca39013553726
# Successfully built noML
# ...

# %%
pip install pandas_ta
# Out:
# ...
#      |████████████████████████████████| 92kB 3.5MB/s
# ...
#   Created wheel for pandas-ta: filename=pandas_ta-0.2.45b0-cp37-none-any.whl size=175305 sha256=dff9947b275460adedc1637f665f2116f31cb5d3a5ca43eae80e0582b36b88f0
#   Stored in directory: /root/.cache/pip/wheels/78/76/74/e4b09c98fc91d7e1e0a56f4fe067796f216deacaa509234579
# Successfully built pandas-ta
# ...

# %%
pip install yfinance
# Out:
# ...
#      |████████████████████████████████| 5.5MB 7.4MB/s
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.59-py2.py3-none-any.whl size=23442 sha256=d8e096cd695b3fc28c6dd5298215ef7373d13457e3dd833a61ef622f95aced79
#   Stored in directory: /root/.cache/pip/wheels/f8/2a/0f/4b5a86e1d52e451757eb6bc17fd899629f0925c777741b6d04
# Successfully built yfinance
# ...
#   Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %%
# Python3 Program to find 
# best buying and selling days

# This function finds the buy sell
# schedule for maximum profit
def stockBuySell(price, n):
	
	# Prices must be given for at least two days
	if (n == 1):
		return
	
	# Traverse through given price array
	i = 0
	while (i < (n - 1)):
		
		# Find Local Minima
		# Note that the limit is (n-2) as we are
		# comparing present element to the next element
		while ((i < (n - 1)) and
				(price[i + 1] <= price[i])):
			i += 1
		
		# If we reached the end, break
		# as no further solution possible
		if (i == n - 1):
			break
		
		# Store the index of minima
		buy = i
		i += 1
		
		# Find Local Maxima
		# Note that the limit is (n-1) as we are
		# comparing to previous element
		while ((i < n) and (price[i] >= price[i - 1])):
			i += 1
			
		# Store the index of maxima
		sell = i - 1
		
		print("Buy on day: ",buy,"\t",
				"Sell on day: ",sell)
		
# Driver code

# Stock prices on consecutive days
price = [100, 180, 260, 310, 40, 535, 695]
n = len(price)

# Fucntion call
stockBuySell(price, n)

# This is code contributed by SHUBHAMSINGH10
# Out:
# Buy on day:  0 	 Sell on day:  3
# Buy on day:  4 	 Sell on day:  6

# %%
import pandas as pd
import yfinance as yf

# %%
tsla_df = yf.download('TSLA', 
                      start='2019-01-01', 
                      end='2019-12-31', 
                      progress=False)

# %%
pip install noML

# %%
import pandas as pd
import numpy as np
import noML as noML

# %%
df = pd.read_csv('master_df_wo_ohlcv.csv')
df.head()
# Out:
#    Unnamed: 0            AD     ADOSC_3_10  ...   VTXP_14   VTXM_14  final_buy
# 0           0 -9.716770e+06 -917075.354697  ...  0.940000  1.080000         no
# 1           1 -1.023245e+07 -993406.503150  ...  0.960001  1.040000         no
# 2           2 -1.023245e+07 -934323.199958  ...  0.940000  1.060001         no
# 3           3 -1.051157e+07 -914024.557747  ...  0.959183  1.061225         no
# 4           4 -1.067461e+07 -874504.107956  ...  0.979167  1.041667         no
#
# [5 rows x 185 columns]

# %%
df.drop(['Unnamed: 0'],inplace=True,axis=1)

# %%
df.columns
# Out:
# Index(['AD', 'ADOSC_3_10', 'ABER_ZG_5_15', 'ABER_SG_5_15', 'ABER_XG_5_15',
#        'ABER_ATR_5_15', 'ACCBL_20', 'ACCBM_20', 'ACCBU_20', 'AMATe_LR_2',
#        ...
#        'VWMA_10', 'WCP', 'WILLR_14', 'WMA_10', 'ZL_EMA_10', 'Z_30', 'VIDYA_14',
#        'VTXP_14', 'VTXM_14', 'final_buy'],
#       dtype='object', length=184)

# %%
X = df.drop(['final_buy'],axis=1)
y = df.final_buy

# %%
a = noML.AutoML(X,y)

# %%
X_train, X_test = a.feature_selection_all()
# Out:
# 1
# ['SQZ_NO']
# total drop columns , 152
# We drop this columns because they highly +ve correlated
# ...

# %%
X_train.shape
# Out:
# (13920, 30)

# %%
a.fit()
# Out:
# KNN
# Logisitc Regression
# Gaussian NavieBayes
# Decision Tree Classifier
# Support vector machine
# Random Forest Classifier
# SGD Classifier
#    Accuracy                 Algorithm  ...  Recall score  time(sec)
# 0  0.730172                       KNN  ...      0.730172   0.096830
# 1  0.790230       Logisitc Regression  ...      0.790230   1.095531
# 2  0.785057       Gaussian NavieBayes  ...      0.785057   0.050600
# 3  0.762069  Decision Tree Classifier  ...      0.762069   0.434066
# 4  0.797414    Support vector machine  ...      0.797414   9.677472
# 5  0.816954  Random Forest Classifier  ...      0.816954   4.754055
# 6  0.533621            SGD Classifier  ...      0.533621   0.391944
#
# [7 rows x 6 columns]

# %%
model = a.randomforest()
# Out:
# Random Forest Classifier

# %%
print(model.predict(X_test))
# Out:
# ['no' 'no' 'buy' ... 'no' 'no' 'no']

# %%
model.score(X_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-d3b3987fd8a5> in <module>()
# ----> 1 model.score(X_test,y_test)
#
# NameError: name 'y_test' is not defined

# %%
X_train.columns
# Out:
# Index(['AD', 'ADOSC_3_10', 'ABER_ZG_5_15', 'AMATe_LR_2', 'AMATe_SR_2',
#        'AO_5_34', 'AROOND_14', 'AROONU_14', 'ADX_14', 'BBB_5_2.0', 'BOP',
#        'CDL_DOJI_10_0.1', 'CHOP_14_1_100', 'CMF_20', 'DEC_1', 'DPO_20',
#        'EFI_13', 'EOM_14_100000000', 'ER_10', 'CDL_INSIDE', 'CFO_9',
#        'MASSI_9_25', 'NVI_1', 'PVO_12_26_9', 'PSARaf_0.02_0.2',
#        'PSARr_0.02_0.2', 'SQZ_ON', 'SQZ_OFF', 'THERMOl_20_2_0.5',
#        'THERMOs_20_2_0.5'],
#       dtype='object')

# %%
tests = df[['AD', 'ADOSC_3_10', 'ABER_ZG_5_15', 'AMATe_LR_2', 'AMATe_SR_2',
       'AO_5_34', 'AROOND_14', 'AROONU_14', 'ADX_14', 'BBB_5_2.0', 'BOP',
       'CDL_DOJI_10_0.1', 'CHOP_14_1_100', 'CMF_20', 'DEC_1', 'DPO_20',
       'EFI_13', 'EOM_14_100000000', 'ER_10', 'CDL_INSIDE', 'CFO_9',
       'MASSI_9_25', 'NVI_1', 'PVO_12_26_9', 'PSARaf_0.02_0.2',
       'PSARr_0.02_0.2', 'SQZ_ON', 'SQZ_OFF', 'THERMOl_20_2_0.5',
       'THERMOs_20_2_0.5']].iloc[699]

# %%
# tests.values.reshape((-1,1))

# %%
model.predict([tests.values])
# Out:
# array(['sell'], dtype=object)

# %%
df.iloc[686]
# Out:
# AD              1.62224e+07
# ADOSC_3_10      1.36955e+06
# ABER_ZG_5_15        50.8733
# ABER_SG_5_15        51.4821
# ABER_XG_5_15        50.2645
#                    ...
# Z_30              -0.697799
# VIDYA_14             51.866
# VTXP_14            0.978261
# VTXM_14             1.00543
# final_buy               buy
# Name: 686, Length: 184, dtype: object

# %%
df[df['final_buy'] == 'buy']
# Out:
#                  AD    ADOSC_3_10  ABER_ZG_5_15  ...   VTXP_14   VTXM_14  final_buy
# 686    1.622236e+07  1.369554e+06     50.873333  ...  0.978261  1.005435        buy
# 984   -1.686654e+07 -1.376879e+06     73.883332  ...  0.820513  1.256411        buy
# 1068  -4.447656e+06 -5.164392e+05     75.080000  ...  0.709090  1.240909        buy
# 1234   4.246877e+07 -2.763651e+06     83.433335  ...  1.155280  0.807453        buy
# 1250   4.403575e+07  1.902220e+06     86.566667  ...  0.925795  1.091873        buy
# ...             ...           ...           ...  ...       ...       ...        ...
# 17373 -1.058951e+05  1.387660e+03   1718.740007  ...  0.647414  1.259259        buy
# 17380 -1.187854e+05 -4.934657e+03   1679.420003  ...  0.629274  1.285243        buy
# 17385 -1.276483e+05 -3.682223e+03   1671.279980  ...  0.731741  1.292140        buy
# 17391 -2.221469e+05 -4.743421e+04   1647.019995  ...  0.700159  1.286171        buy
# ...

# %%
df[df['final_buy'] == 'sell']
# Out:
#                  AD    ADOSC_3_10  ABER_ZG_5_15  ...   VTXP_14   VTXM_14  final_buy
# 692    2.627088e+07  4.179464e+06     51.890000  ...  1.257485  0.736526       sell
# 699    7.883420e+06  2.524276e+06     57.370000  ...  1.372882  0.508474       sell
# 990    9.252404e+06  1.029133e+07     75.046667  ...  1.239131  0.679347       sell
# 1074  -1.285515e+06  9.199342e+05     75.906667  ...  0.763888  1.208333       sell
# 1236   4.605497e+07 -2.738868e+06     85.313334  ...  1.145593  0.681992       sell
# ...             ...           ...           ...  ...       ...       ...        ...
# 17370 -1.028565e+05 -7.958109e+03   1759.360002  ...  0.769442  1.218884       sell
# 17375 -7.224308e+04  2.108565e+04   1713.576676  ...  0.796938  1.195754       sell
# 17381 -8.145269e+04  1.023172e+04   1673.319995  ...  0.678472  1.259956       sell
# 17386 -1.159214e+05 -2.073183e+03   1669.843311  ...  0.779681  1.260377       sell
# ...

# %%
import datetime as dt
import yfinance as yf
import pandas_ta as ta
start = dt.datetime.today()-dt.timedelta(10)
end = dt.datetime.today()
df = yf.download('ITC.NS',start=start, end=end,interval='15m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 139 entries, 2021-04-19 09:15:00+05:30 to 2021-04-27 12:17:25+05:30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   open       139 non-null    float64
#  1   high       139 non-null    float64
#  2   low        139 non-null    float64
#  3   close      139 non-null    float64
#  4   adj_close  139 non-null    float64
#  5   volume     139 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 7.6 KB

# %%
df.ta.strategy(ta.AllStrategy)

# %%
df

# %%
df = df[['AD', 'ADOSC_3_10', 'ABER_ZG_5_15', 'AMATe_LR_2', 'AMATe_SR_2',
       'AO_5_34', 'AROOND_14', 'AROONU_14', 'ADX_14', 'BBB_5_2.0', 'BOP',
       'CDL_DOJI_10_0.1', 'CHOP_14_1_100', 'CMF_20', 'DEC_1', 'DPO_20',
       'EFI_13', 'EOM_14_100000000', 'ER_10', 'CDL_INSIDE', 'CFO_9',
       'MASSI_9_25', 'NVI_1', 'PVO_12_26_9', 'PSARaf_0.02_0.2',
       'PSARr_0.02_0.2', 'SQZ_ON', 'SQZ_OFF', 'THERMOl_20_2_0.5',
       'THERMOs_20_2_0.5']]

# %%
import pandas as pd
import yfinance as yf
import datetime as dt
import pandas_ta as ta


# This function finds the buy sell
# schedule for maximum profit
def stockBuySell(tick):
    
    start = dt.datetime.today()-dt.timedelta(7)
    end = dt.datetime.today()
    fdf = yf.download(tick,start=start, end=end,interval='1m')
    fdf.ta.strategy(ta.AllStrategy)
    price = fdf['close']
    n = len(fdf)
    
    fdf['final_buy'] = 'no'
    # fdf['final_sell'] = 'no'
    # fdf['profit'] = 0
    total = 0
    # Prices must be given for at least two days
    if (n == 1):
        return
    
    # Traverse through given price array
    i = 0
    while (i < (n - 1)):
        
        # Find Local Minima
        # Note that the limit is (n-2) as we are
        # comparing present element to the next element
        while ((i < (n - 1)) and
                (price[i + 1] <= price[i])):
            i += 1
        
        # If we reached the end, break
        # as no further solution possible
        if (i == n - 1):
            break
        
        # Store the index of minima
        buy = i
        i += 1
        
        # Find Local Maxima
        # Note that the limit is (n-1) as we are
        # comparing to previous element
        while ((i < n) and (price[i] >= price[i - 1])):
            i += 1
            
        # Store the index of maxima
        sell = i - 1
        
        profit = fdf['close'][sell] - fdf['close'][buy]
        
        if (profit >= 2):
            
            print("Buy on day: ",buy,"\t", "Sell on day: ",sell,"\t", "Profit: ",profit)  
            total = total + profit
            # print(total)
            fdf['final_buy'][buy] = 'buy'
            fdf['final_buy'][sell] = 'sell'
            # fdf['profit'][sell] = profit
    fdf.drop(['open', 'high', 'low', 'close', 'adj_close', 'volume','HILOs_13_21','HILOl_13_21','SUPERTl_7_3.0','QQEs_14_5_4.236','PSARs_0.02_0.2','PSARl_0.02_0.2','SUPERTs_7_3.0','QQEl_14_5_4.236'],axis=1,inplace=True)
    fdf = fdf.dropna()
    fdf = fdf.reset_index(drop=True)
    return fdf

# %%
df = stockBuySell('TCS.NS')
# Out:
# [*********************100%***********************]  1 of 1 completed
# Buy on day:  3 	 Sell on day:  6 	 Profit:  7.25
# Buy on day:  7 	 Sell on day:  8 	 Profit:  5.349853515625
# Buy on day:  9 	 Sell on day:  11 	 Profit:  2.35009765625
# Buy on day:  14 	 Sell on day:  15 	 Profit:  3.39990234375
# Buy on day:  19 	 Sell on day:  22 	 Profit:  10.900146484375
# Buy on day:  23 	 Sell on day:  27 	 Profit:  14.5
# Buy on day:  32 	 Sell on day:  34 	 Profit:  4.050048828125
# Buy on day:  45 	 Sell on day:  46 	 Profit:  3.0
# Buy on day:  49 	 Sell on day:  50 	 Profit:  3.150146484375
# Buy on day:  63 	 Sell on day:  66 	 Profit:  2.300048828125
# Buy on day:  69 	 Sell on day:  75 	 Profit:  7.050048828125
# Buy on day:  81 	 Sell on day:  84 	 Profit:  3.800048828125
# Buy on day:  88 	 Sell on day:  89 	 Profit:  4.64990234375
# Buy on day:  91 	 Sell on day:  95 	 Profit:  2.2001953125
# Buy on day:  99 	 Sell on day:  101 	 Profit:  2.14990234375
# ...

# %%
df.head()
# Out:
#              AD   ADOSC_3_10  ABER_ZG_5_15  ...   VTXP_14   VTXM_14  final_buy
# 0 -60767.907603  -731.719896   3124.989990  ...  1.132260  0.904841         no
# 1 -59924.672110  -634.414226   3124.840007  ...  1.100495  0.917621         no
# 2 -59069.962249  -264.980203   3124.766683  ...  1.093273  0.831805         no
# 3 -60675.323723  -600.555826   3124.413346  ...  1.059427  0.909361         no
# 4 -62704.323723 -1328.831687   3123.786686  ...  1.064698  0.879043        buy
#
# [5 rows x 184 columns]

# %%
df.shape
# Out:
# (1354, 184)

# %%
X = df[['AD', 'ADOSC_3_10', 'ABER_ZG_5_15', 'AMATe_LR_2', 'AMATe_SR_2',
       'AO_5_34', 'AROOND_14', 'AROONU_14', 'ADX_14', 'BBB_5_2.0', 'BOP',
       'CDL_DOJI_10_0.1', 'CHOP_14_1_100', 'CMF_20', 'DEC_1', 'DPO_20',
       'EFI_13', 'EOM_14_100000000', 'ER_10', 'CDL_INSIDE', 'CFO_9',
       'MASSI_9_25', 'NVI_1', 'PVO_12_26_9', 'PSARaf_0.02_0.2',
       'PSARr_0.02_0.2', 'SQZ_ON', 'SQZ_OFF', 'THERMOl_20_2_0.5',
       'THERMOs_20_2_0.5']].iloc[100:]

y = df.final_buy.iloc[100:]

# %%
X.shape
# Out:
# (1254, 30)

# %%
import noML
tp = noML.AutoML(X,y)

# %%
tp.fit()
# Out:
# KNN
# Logisitc Regression
# Gaussian NavieBayes
# Decision Tree Classifier
# Support vector machine
# Random Forest Classifier
# SGD Classifier
#    Accuracy                 Algorithm  ...  Recall score  time(sec)
# 0  0.669323                       KNN  ...      0.669323   0.012046
# 1  0.713147       Logisitc Regression  ...      0.713147   0.095461
# 2  0.645418       Gaussian NavieBayes  ...      0.645418   0.004486
# 3  0.685259  Decision Tree Classifier  ...      0.685259   0.023244
# 4  0.725100    Support vector machine  ...      0.725100   0.057072
# 5  0.752988  Random Forest Classifier  ...      0.752988   0.385397
# 6  0.705179            SGD Classifier  ...      0.705179   0.031218
#
# [7 rows x 6 columns]

# %%
model = tp.randomforest()
# Out:
# Random Forest Classifier

# %%
zx = df[['AD', 'ADOSC_3_10', 'ABER_ZG_5_15', 'AMATe_LR_2', 'AMATe_SR_2',
       'AO_5_34', 'AROOND_14', 'AROONU_14', 'ADX_14', 'BBB_5_2.0', 'BOP',
       'CDL_DOJI_10_0.1', 'CHOP_14_1_100', 'CMF_20', 'DEC_1', 'DPO_20',
       'EFI_13', 'EOM_14_100000000', 'ER_10', 'CDL_INSIDE', 'CFO_9',
       'MASSI_9_25', 'NVI_1', 'PVO_12_26_9', 'PSARaf_0.02_0.2',
       'PSARr_0.02_0.2', 'SQZ_ON', 'SQZ_OFF', 'THERMOl_20_2_0.5',
       'THERMOs_20_2_0.5']].iloc[790:]
zy = df.final_buy.iloc[790:]
 
zx = zx.reset_index(drop=True)
zy = zy.reset_index(drop=True)

# %%
array = zy[zy=='buy'].index
array
for i in array:
    print(model.predict([zx.iloc[i]]))
# Out:
# ['no']
# ['buy']
# ['buy']
# ['buy']
# ['buy']
# ['buy']
# ['no']
# ['buy']
# ['no']
# ['buy']
# ['no']
# ['buy']
# ['buy']
# ['buy']
# ['buy']
# ['buy']
# ['buy']
# ['buy']
# ['buy']
# ['no']
# ['buy']
# ['buy']
# ['buy']
# ['buy']
# ['buy']
# ['no']
# ['buy']
# ['buy']
# ['buy']
# ['buy']
# ['buy']
# ['buy']
# ['buy']
# ['buy']
# ['no']
# ['buy']
# ['buy']
# ['buy']
# ['no']
# ['buy']
# ['no']
# ['buy']
# ['buy']
# ['buy']
# ['buy']
# ['buy']
# ['buy']
# ['buy']
# ['buy']
# ['no']
# ['buy']
# ['buy']
# ['buy']
# ['buy']
# ['no']
# ['no']
# ['buy']
# ['no']
# ['buy']

# %%
array = zy[zy=='buy'].index

# %%
array
# Out:
# Int64Index([0, 4, 12, 14], dtype='int64')

# %%
for i in array:
    print(model.predict([zx.iloc[i]]))
# Out:
# ['no']
# ['buy']
# ['no']
# ['no']

# %%
ls
# Out:
# BHEL__EQ__NSE__NSE__MINUTE.csv  sample_data/

# %%
bhel = pd.read_csv('bhel.csv')
bhel = bhel.reset_index(drop=True)
bhel = bhel.set_index(['timestamp'])
bhel.head()
# Out:
#                             open   high    low  close   volume
# timestamp
# 2017-01-02 09:15:00+05:30  80.83  81.00  80.83  80.90  29495.0
# 2017-01-02 09:16:00+05:30  80.90  80.90  80.77  80.90  25445.0
# 2017-01-02 09:17:00+05:30  80.87  80.93  80.77  80.80  23282.0
# 2017-01-02 09:18:00+05:30  80.80  80.80  80.67  80.77  31247.0
# 2017-01-02 09:19:00+05:30  80.77  80.80  80.53  80.60  22892.0

# %%
bhel.index = pd.to_datetime(bhel.index)

# %%
type(bhel.index[1])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# bhel = bhel.resample("15T").mean()

# %%
import pandas as pd
import yfinance as yf
import datetime as dt
import pandas_ta as ta


# This function finds the buy sell
# schedule for maximum profit
def stockBuySelldf(df):
    fdf = df.copy()
    # start = dt.datetime.today()-dt.timedelta(59)
    # end = dt.datetime.today()
    # fdf = yf.download(tick,start=start, end=end,interval='15m')
    # fdf.ta.strategy(ta.AllStrategy)
    price = fdf['close']
    n = len(fdf)
    
    fdf['final_buy'] = 'no'
    # fdf['final_sell'] = 'no'
    # fdf['profit'] = 0
    total = 0
    # Prices must be given for at least two days
    if (n == 1):
        return
    
    # Traverse through given price array
    i = 0
    while (i < (n - 1)):
        
        # Find Local Minima
        # Note that the limit is (n-2) as we are
        # comparing present element to the next element
        while ((i < (n - 1)) and
                (price[i + 1] <= price[i])):
            i += 1
        
        # If we reached the end, break
        # as no further solution possible
        if (i == n - 1):
            break
        
        # Store the index of minima
        buy = i
        i += 1
        
        # Find Local Maxima
        # Note that the limit is (n-1) as we are
        # comparing to previous element
        while ((i < n) and (price[i] >= price[i - 1])):
            i += 1
            
        # Store the index of maxima
        sell = i - 1
        
        profit = fdf['close'][sell] - fdf['close'][buy]
        
        if (profit >= 2):
            
            print("Buy on day: ",buy,"\t", "Sell on day: ",sell,"\t", "Profit: ",profit)  
            total = total + profit
            # print(total)
            fdf['final_buy'][buy] = 'buy'
            fdf['final_buy'][sell] = 'sell'
            # fdf['profit'][sell] = profit
    # fdf.drop(['open', 'high', 'low', 'close'],axis=1,inplace=True)
    # fdf = fdf.dropna()
    # fdf = fdf.reset_index(drop=True)
    return fdf

# %%
bhel.isnull().sum()
# Out:
# open      138
# high      138
# low       138
# close     138
# volume    138
# dtype: int64

# %%
bhel.dropna(inplace=True)

# %%
bhel.shape
# Out:
# (370407, 5)

# %%
sample_bhel = bhel.iloc[367454:]

# %%
sample_bhel = sample_bhel.dropna()

# %%
sample_bhel.shape
# Out:
# (2953, 5)

# %%
sample_bhel.to_csv('sample_bhel.csv')

# %%
sample_bhel.head()
# Out:
#                             open  high    low  close    volume
# timestamp
# 2020-12-22 10:02:00+05:30  31.50  31.5  31.40  31.50  240996.0
# 2020-12-22 10:03:00+05:30  31.45  31.5  31.40  31.45  247630.0
# 2020-12-22 10:04:00+05:30  31.50  31.6  31.45  31.55  299612.0
# 2020-12-22 10:05:00+05:30  31.55  31.6  31.45  31.55  175819.0
# 2020-12-22 10:06:00+05:30  31.55  31.6  31.45  31.55  145229.0

# %%
sample_bhel.isnull().sum()
# Out:
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64

# %%
sample_bhel.ta.strategy(ta.AllStrategy)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/arrays/datetimes.py:1092: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/pandas/core/arrays/datetimes.py:1092: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   UserWarning,

# %%
sample_bhel
# Out:
#                             open   high    low  ...   VIDYA_14   VTXP_14   VTXM_14
# timestamp                                       ...
# 2020-12-22 10:02:00+05:30  31.50  31.50  31.40  ...        NaN       NaN       NaN
# 2020-12-22 10:03:00+05:30  31.45  31.50  31.40  ...        NaN       NaN       NaN
# 2020-12-22 10:04:00+05:30  31.50  31.60  31.45  ...        NaN       NaN       NaN
# 2020-12-22 10:05:00+05:30  31.55  31.60  31.45  ...        NaN       NaN       NaN
# 2020-12-22 10:06:00+05:30  31.55  31.60  31.45  ...        NaN       NaN       NaN
# ...                          ...    ...    ...  ...        ...       ...       ...
# 2021-01-01 15:25:00+05:30  38.60  38.65  38.60  ...  38.542757  0.975610  1.048780
# 2021-01-01 15:26:00+05:30  38.60  38.65  38.55  ...  38.545693  0.947368  1.131579
# 2021-01-01 15:27:00+05:30  38.65  38.70  38.60  ...  38.551042  0.894737  1.105263
# 2021-01-01 15:28:00+05:30  38.65  38.70  38.60  ...  38.553840  0.864865  1.162162
# ...

# %%
bhell = stockBuySelldf(sample_bhel)

# %%
bhell.final_buy.unique()
# Out:
# array(['no'], dtype=object)

# %%
import pandas as pd
import yfinance as yf
import datetime as dt
import pandas_ta as ta


# This function finds the buy sell
# schedule for maximum profit
def stockBuySelldirect(link):
    fdf = pd.read_csv(link)
    # start = dt.datetime.today()-dt.timedelta(59)
    # end = dt.datetime.today()
    # fdf = yf.download(tick,start=start, end=end,interval='15m')
    fdf.ta.strategy(ta.AllStrategy)
    price = fdf['close']
    n = len(fdf)
    
    fdf['final_buy'] = 'no'
    # fdf['final_sell'] = 'no'
    # fdf['profit'] = 0
    total = 0
    # Prices must be given for at least two days
    if (n == 1):
        return
    
    # Traverse through given price array
    i = 0
    while (i < (n - 1)):
        
        # Find Local Minima
        # Note that the limit is (n-2) as we are
        # comparing present element to the next element
        while ((i < (n - 1)) and
                (price[i + 1] <= price[i])):
            i += 1
        
        # If we reached the end, break
        # as no further solution possible
        if (i == n - 1):
            break
        
        # Store the index of minima
        buy = i
        i += 1
        
        # Find Local Maxima
        # Note that the limit is (n-1) as we are
        # comparing to previous element
        while ((i < n) and (price[i] >= price[i - 1])):
            i += 1
            
        # Store the index of maxima
        sell = i - 1
        
        profit = fdf['close'][sell] - fdf['close'][buy]
        
        if (profit >= 2):
            
            print("Buy on day: ",buy,"\t", "Sell on day: ",sell,"\t", "Profit: ",profit)  
            total = total + profit
            # print(total)
            fdf['final_buy'][buy] = 'buy'
            fdf['final_buy'][sell] = 'sell'
            # fdf['profit'][sell] = profit
    fdf.drop(['open', 'high', 'low', 'close', 'adj_close', 'volume','HILOs_13_21','HILOl_13_21','SUPERTl_7_3.0','QQEs_14_5_4.236','PSARs_0.02_0.2','PSARl_0.02_0.2','SUPERTs_7_3.0','QQEl_14_5_4.236'],axis=1,inplace=True)
    fdf = fdf.dropna()
    fdf = fdf.reset_index(drop=True)
    return fdf

# %%
link = 'https://raw.githubusercontent.com/rushiai/data_csv/main/master_df_wo_ohlcv.csv'
# a = stockBuySelldirect(link)

# %%
a = pd.read_csv(link)

# %%
a.drop(['Unnamed: 0'], inplace=True, axis=1)

# %%
sample = a.iloc[15000:]

# %%
org = a.iloc[:15001]

# %%
import noML as noML

# %%
X = org.drop(['final_buy'],axis=1)
y = org.final_buy

# %%
tp = noML.AutoML(X,y)

# %%
X_train, X_test = tp.feature_selection_all()
# Out:
# 1
# ['SQZ_NO']
# total drop columns , 152
# We drop this columns because they highly +ve correlated
# ...

# %%
X_train.columns
# Out:
# Index(['AD', 'ADOSC_3_10', 'ABER_ZG_5_15', 'AMATe_LR_2', 'AMATe_SR_2',
#        'AO_5_34', 'AROOND_14', 'AROONU_14', 'ADX_14', 'BBB_5_2.0', 'BOP',
#        'CDL_DOJI_10_0.1', 'CHOP_14_1_100', 'CMF_20', 'DEC_1', 'DPO_20',
#        'EFI_13', 'EOM_14_100000000', 'ER_10', 'CDL_INSIDE', 'CFO_9', 'KURT_30',
#        'NVI_1', 'PVO_12_26_9', 'PSARaf_0.02_0.2', 'PSARr_0.02_0.2', 'SQZ_ON',
#        'SQZ_OFF', 'THERMOl_20_2_0.5', 'THERMOs_20_2_0.5'],
#       dtype='object')

# %%
tp.fit()
# Out:
# KNN
# Logisitc Regression
# Gaussian NavieBayes
# Decision Tree Classifier
# Support vector machine
# Random Forest Classifier
# SGD Classifier
#    Accuracy                 Algorithm  ...  Recall score  time(sec)
# 0  0.757081                       KNN  ...      0.757081   0.089591
# 1  0.832056       Logisitc Regression  ...      0.832056   1.019819
# 2  0.823725       Gaussian NavieBayes  ...      0.823725   0.041374
# 3  0.779074  Decision Tree Classifier  ...      0.779074   0.387399
# 4  0.832389    Support vector machine  ...      0.832389   6.337707
# 5  0.844052  Random Forest Classifier  ...      0.844052   4.062069
# 6  0.110630            SGD Classifier  ...      0.110630   0.274516
#
# [7 rows x 6 columns]

# %%
X_te = sample.drop(['final_buy'],axis=1)
y_te = sample.final_buy

X_te.reset_index(drop=True,inplace=True)
y_te.reset_index(drop=True,inplace=True)

# %%
X_te = X_te[['AD', 'ADOSC_3_10', 'ABER_ZG_5_15', 'AMATe_LR_2', 'AMATe_SR_2',
       'AO_5_34', 'AROOND_14', 'AROONU_14', 'ADX_14', 'BBB_5_2.0', 'BOP',
       'CDL_DOJI_10_0.1', 'CHOP_14_1_100', 'CMF_20', 'DEC_1', 'DPO_20',
       'EFI_13', 'EOM_14_100000000', 'ER_10', 'CDL_INSIDE', 'CFO_9', 'KURT_30',
       'NVI_1', 'PVO_12_26_9', 'PSARaf_0.02_0.2', 'PSARr_0.02_0.2', 'SQZ_ON',
       'SQZ_OFF', 'THERMOl_20_2_0.5', 'THERMOs_20_2_0.5']]

# %%
model = tp.randomforest()
# Out:
# Random Forest Classifier

# %%
# model = tp.hypertune_random('rfclf')

# %%
y_te[y_te=='sell']

# %%
array = y_te[y_te=='buy'].index
array
for i in array:
    print(model.predict([X_te.iloc[i]]))

# %%
pip install autoviz

# %%
import pandas as pd
import yfinance as yf
import datetime as dt
import pandas_ta as ta


# This function finds the buy sell
# schedule for maximum profit
def stockBuySell(fdf):
    
    # start = dt.datetime.today()-dt.timedelta(59)
    # end = dt.datetime.today()
    # fdf = yf.download(tick,start=start, end=end,interval='15m')
    # fdf.ta.strategy(ta.AllStrategy)
    price = fdf['close']
    n = len(fdf)
    
    fdf['final_buy'] = 'no'
    # fdf['final_sell'] = 'no'
    # fdf['profit'] = 0
    total = 0
    # Prices must be given for at least two days
    if (n == 1):
        return
    
    # Traverse through given price array
    i = 0
    while (i < (n - 1)):
        
        # Find Local Minima
        # Note that the limit is (n-2) as we are
        # comparing present element to the next element
        while ((i < (n - 1)) and
                (price[i + 1] <= price[i])):
            i += 1
        
        # If we reached the end, break
        # as no further solution possible
        if (i == n - 1):
            break
        
        # Store the index of minima
        buy = i
        i += 1
        
        # Find Local Maxima
        # Note that the limit is (n-1) as we are
        # comparing to previous element
        while ((i < n) and (price[i] >= price[i - 1])):
            i += 1
            
        # Store the index of maxima
        sell = i - 1
        
        profit = fdf['close'][sell] - fdf['close'][buy]
        
        if (profit >= 2):
            
            print("Buy on day: ",buy,"\t", "Sell on day: ",sell,"\t", "Profit: ",profit)  
            total = total + profit
            # print(total)
            fdf['final_buy'][buy] = 'buy'
            fdf['final_buy'][sell] = 'sell'
            # fdf['profit'][sell] = profit
    # fdf.drop(['open', 'high', 'low', 'close', 'adj_close', 'volume','HILOs_13_21','HILOl_13_21','SUPERTl_7_3.0','QQEs_14_5_4.236','PSARs_0.02_0.2','PSARl_0.02_0.2','SUPERTs_7_3.0','QQEl_14_5_4.236'],axis=1,inplace=True)
    fdf = fdf.dropna()
    fdf = fdf.reset_index(drop=True)
    return fdf

# %%
link = 'https://raw.githubusercontent.com/rushiai/data_csv/main/AXISBANK__EQ__NSE__NSE__MINUTE.csv'

# %%
bhel = pd.read_csv(link)

# %%
bhel.head()
# Out:
#                    timestamp    open    high     low   close   volume
# 0  2017-01-02 09:15:00+05:30  451.40  452.00  450.60  451.20  29198.0
# 1  2017-01-02 09:16:00+05:30  451.15  451.15  450.50  450.80  12539.0
# 2  2017-01-02 09:17:00+05:30  450.50  450.80  449.30  449.30  26833.0
# 3  2017-01-02 09:18:00+05:30  449.30  450.10  448.95  449.75  12067.0
# 4  2017-01-02 09:19:00+05:30  449.75  450.30  449.25  449.80  15675.0

# %%
bhel.isna().sum()
# Out:
# timestamp    0
# open         0
# high         0
# low          0
# close        0
# volume       0
# dtype: int64

# %%
namee = bhel.isna().sum().index

# %%
namee
# Out:
# Index(['timestamp', 'open', 'high', 'low', 'close', 'volume'], dtype='object')

# %%
mean = bhel['volume'].mean()
bhel['volume'].fillna(value=mean, inplace=True)

# %%
bhel.shape
# Out:
# (370546, 6)

# %%
sample_bhel.iloc[10]
# Out:
# timestamp        2020-12-21 14:08:00+05:30
# open                                 596.9
# high                                 596.9
# low                                  596.2
# close                                596.6
# volume                               23094
# AD                                -50827.2
# ADOSC_3_10                         11332.9
# ABER_ZG_5_15                       596.487
# ABER_SG_5_15                           NaN
# ABER_XG_5_15                           NaN
# ABER_ATR_5_15                          NaN
# ACCBL_20                               NaN
# ACCBM_20                               NaN
# ACCBU_20                               NaN
# Name: 367464, dtype: object

# %%
pip install -U git+https://github.com/twopirllc/pandas-ta
# Out:
# ...
#   Cloning https://github.com/twopirllc/pandas-ta to /tmp/pip-req-build-ibd4q85h
#   Running command git clone -q https://github.com/twopirllc/pandas-ta /tmp/pip-req-build-ibd4q85h
# ...
#   Created wheel for pandas-ta: filename=pandas_ta-0.2.67b0-cp37-none-any.whl size=188709 sha256=21903372e690bb2ef13fc3c83ec283f1f297cd127ddee3b854564e4d8ccf6678
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ro7kth_6/wheels/64/67/96/15e918c3b53b4a323b5bd037c7f08be5ef6908141c50f07c76
# Successfully built pandas-ta
# ...
#   Found existing installation: pandas-ta 0.2.67b0
#     Uninstalling pandas-ta-0.2.67b0:
#       Successfully uninstalled pandas-ta-0.2.67b0
# ...

# %%
import pandas_ta as ta
import warnings
warnings.filterwarnings("ignore")

# %%
sample_bhel = bhel.iloc[367474:]
sample_bhel.to_csv('sample_bhel.csv')
bhel.ta.strategy(ta.AllStrategy)
# Out:
# [!] VWAP volume series is not datetime ordered. Results may not be as expected.
# [!] VWAP price series is not datetime ordered. Results may not be as expected.
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/local/lib/python3.7/dist-packages/pandas_ta/core.py", line 429, in _mp_worker
#   File "/usr/local/lib/python3.7/dist-packages/pandas_ta/core.py", line 1154, in vwap
#     return result, span
#   File "/usr/local/lib/python3.7/dist-packages/pandas_ta/overlap/vwap.py", line 23, in vwap
#     vwap  = wp.groupby(wp.index.to_period(anchor)).cumsum()
# ...

# %%
bhel.head

# %%
bhel.to_csv('bhel_with_ta.csv')

# %%
tsla_intra.shape
# Out:
# (100, 5)

# %%
mic = pd.read_csv('20mic.csv')
mic.shape
# Out:
# (2857, 7)

# %%
mic.ta.strategy(ta.AllStrategy)
# Out:
# [!] VWAP volume series is not datetime ordered. Results may not be as expected.
# [!] VWAP price series is not datetime ordered. Results may not be as expected.
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/local/lib/python3.7/dist-packages/pandas_ta/core.py", line 429, in _mp_worker
#   File "/usr/local/lib/python3.7/dist-packages/pandas_ta/core.py", line 1154, in vwap
#     return result, span
#   File "/usr/local/lib/python3.7/dist-packages/pandas_ta/overlap/vwap.py", line 23, in vwap
#     vwap  = wp.groupby(wp.index.to_period(anchor)).cumsum()
# ...

# %%
import pandas as pd
import yfinance as yf
import datetime as dt
import pandas_ta as ta


# This function finds the buy sell
# schedule for maximum profit
def stockBuySell(fdf):
    
    # start = dt.datetime.today()-dt.timedelta(7)
    # end = dt.datetime.today()
    # fdf = yf.download(tick,start=start, end=end,interval='1m')
    # fdf.ta.strategy(ta.AllStrategy)
    price = fdf['close']
    n = len(fdf)
    
    fdf['final_buy'] = 'no'
    # fdf['final_sell'] = 'no'
    # fdf['profit'] = 0
    total = 0
    # Prices must be given for at least two days
    if (n == 1):
        return
    
    # Traverse through given price array
    i = 0
    while (i < (n - 1)):
        
        # Find Local Minima
        # Note that the limit is (n-2) as we are
        # comparing present element to the next element
        while ((i < (n - 1)) and
                (price[i + 1] <= price[i])):
            i += 1
        
        # If we reached the end, break
        # as no further solution possible
        if (i == n - 1):
            break
        
        # Store the index of minima
        buy = i
        i += 1
        
        # Find Local Maxima
        # Note that the limit is (n-1) as we are
        # comparing to previous element
        while ((i < n) and (price[i] >= price[i - 1])):
            i += 1
            
        # Store the index of maxima
        sell = i - 1
        
        profit = fdf['close'][sell] - fdf['close'][buy]
        
        if (profit >= 2):
            
            print("Buy on day: ",buy,"\t", "Sell on day: ",sell,"\t", "Profit: ",profit)  
            total = total + profit
            # print(total)
            fdf['final_buy'][buy] = 'buy'
            fdf['final_buy'][sell] = 'sell'
            # fdf['profit'][sell] = profit
    # fdf.drop(['open', 'high', 'low', 'close', 'adj_close', 'volume','HILOs_13_21','HILOl_13_21','SUPERTl_7_3.0','QQEs_14_5_4.236','PSARs_0.02_0.2','PSARl_0.02_0.2','SUPERTs_7_3.0','QQEl_14_5_4.236'],axis=1,inplace=True)
    # fdf = fdf.dropna()
    # fdf = fdf.reset_index(drop=True)
    return fdf

# %%
import pandas as pd

# %%
link = 'https://raw.githubusercontent.com/rushiai/data_csv/main/AXISBANK__EQ__NSE__NSE__MINUTE.csv'
df = pd.read_csv(link)
df = df.set_index(['timestamp'])
df.index = pd.to_datetime(df.index)
df.head()
# Out:
#                              open    high     low   close   volume
# timestamp
# 2017-01-02 09:15:00+05:30  451.40  452.00  450.60  451.20  29198.0
# 2017-01-02 09:16:00+05:30  451.15  451.15  450.50  450.80  12539.0
# 2017-01-02 09:17:00+05:30  450.50  450.80  449.30  449.30  26833.0
# 2017-01-02 09:18:00+05:30  449.30  450.10  448.95  449.75  12067.0
# 2017-01-02 09:19:00+05:30  449.75  450.30  449.25  449.80  15675.0

# %%
vol = df.resample('15min').sum().volume
price = df['close'].resample('15Min').ohlc()

# %%
ndf = pd.concat([price, vol], axis=1)

# %%
ndf
# Out:
#                              open    high     low   close    volume
# timestamp
# 2017-01-02 09:15:00+05:30  451.20  451.65  448.95  448.95  211638.0
# 2017-01-02 09:30:00+05:30  448.05  449.05  447.50  447.50  117877.0
# 2017-01-02 09:45:00+05:30  445.80  447.00  445.80  446.80  200269.0
# 2017-01-02 10:00:00+05:30  446.55  447.50  446.35  446.50   62625.0
# 2017-01-02 10:15:00+05:30  446.70  447.15  446.40  446.40   34067.0
# ...                           ...     ...     ...     ...       ...
# 2021-01-01 14:15:00+05:30  622.90  623.90  622.90  623.00  103992.0
# 2021-01-01 14:30:00+05:30  623.05  623.75  623.05  623.70  159480.0
# 2021-01-01 14:45:00+05:30  623.75  623.75  623.15  623.40  131560.0
# 2021-01-01 15:00:00+05:30  622.90  623.90  622.60  623.80  416783.0
# 2021-01-01 15:15:00+05:30  623.95  624.90  622.55  623.40  646648.0
#
# [140185 rows x 5 columns]

# %%
ndf.tail(50)
# Out:
#                              open    high     low   close    volume
# timestamp
# 2021-01-01 03:00:00+05:30     NaN     NaN     NaN     NaN       0.0
# 2021-01-01 03:15:00+05:30     NaN     NaN     NaN     NaN       0.0
# 2021-01-01 03:30:00+05:30     NaN     NaN     NaN     NaN       0.0
# 2021-01-01 03:45:00+05:30     NaN     NaN     NaN     NaN       0.0
# 2021-01-01 04:00:00+05:30     NaN     NaN     NaN     NaN       0.0
# 2021-01-01 04:15:00+05:30     NaN     NaN     NaN     NaN       0.0
# 2021-01-01 04:30:00+05:30     NaN     NaN     NaN     NaN       0.0
# 2021-01-01 04:45:00+05:30     NaN     NaN     NaN     NaN       0.0
# 2021-01-01 05:00:00+05:30     NaN     NaN     NaN     NaN       0.0
# 2021-01-01 05:15:00+05:30     NaN     NaN     NaN     NaN       0.0
# 2021-01-01 05:30:00+05:30     NaN     NaN     NaN     NaN       0.0
# 2021-01-01 05:45:00+05:30     NaN     NaN     NaN     NaN       0.0
# 2021-01-01 06:00:00+05:30     NaN     NaN     NaN     NaN       0.0
# ...

# %%
ndf.to_csv('ndf 15 axis.csv')

# %%
ndf.dropna(inplace=True)

# %%
ndf.isnull().sum()
# Out:
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64

# %%
ndf.shape
# Out:
# (24698, 5)

# %%
temp = ndf.iloc[17698:]

# %%
temp
# Out:
#                              open    high     low   close    volume
# timestamp
# 2019-11-20 15:15:00+05:30  748.50  749.35  748.35  748.40  733256.0
# 2019-11-21 09:15:00+05:30  747.10  747.10  743.70  743.70  580133.0
# 2019-11-21 09:30:00+05:30  743.90  743.90  739.85  740.60  405117.0
# 2019-11-21 09:45:00+05:30  740.50  742.15  738.10  738.10  303053.0
# 2019-11-21 10:00:00+05:30  738.25  740.85  738.25  740.45  185433.0
# ...                           ...     ...     ...     ...       ...
# 2021-01-01 14:15:00+05:30  622.90  623.90  622.90  623.00  103992.0
# 2021-01-01 14:30:00+05:30  623.05  623.75  623.05  623.70  159480.0
# 2021-01-01 14:45:00+05:30  623.75  623.75  623.15  623.40  131560.0
# 2021-01-01 15:00:00+05:30  622.90  623.90  622.60  623.80  416783.0
# 2021-01-01 15:15:00+05:30  623.95  624.90  622.55  623.40  646648.0
#
# [7000 rows x 5 columns]

# %%
train = temp.iloc[0:6000]

# %%
test = temp.iloc[6001:]

# %%
train.ta.strategy(ta.AllStrategy)
test.ta.strategy(ta.AllStrategy)

# %%
trainp = stockBuySell(train)
# Out:
# Buy on day:  3 	 Sell on day:  4 	 Profit:  2.3500000000000227
# Buy on day:  6 	 Sell on day:  8 	 Profit:  3.7000000000000455
# Buy on day:  25 	 Sell on day:  26 	 Profit:  2.8999999999999773
# Buy on day:  45 	 Sell on day:  46 	 Profit:  5.2000000000000455
# Buy on day:  50 	 Sell on day:  52 	 Profit:  7.699999999999932
# Buy on day:  54 	 Sell on day:  57 	 Profit:  3.0499999999999545
# Buy on day:  58 	 Sell on day:  59 	 Profit:  2.25
# Buy on day:  64 	 Sell on day:  74 	 Profit:  16.800000000000068
# Buy on day:  76 	 Sell on day:  77 	 Profit:  3.099999999999909
# Buy on day:  79 	 Sell on day:  86 	 Profit:  6.5499999999999545
# Buy on day:  97 	 Sell on day:  100 	 Profit:  9.5
# Buy on day:  101 	 Sell on day:  102 	 Profit:  7.2000000000000455
# Buy on day:  129 	 Sell on day:  131 	 Profit:  4.7999999999999545
# Buy on day:  135 	 Sell on day:  136 	 Profit:  2.9500000000000455
# Buy on day:  140 	 Sell on day:  141 	 Profit:  4.7999999999999545
# ...

# %%
trainp
# Out:
#                              open    high  ...   VTXM_14  final_buy
# timestamp                                  ...
# 2019-11-20 15:15:00+05:30  748.50  749.35  ...       NaN         no
# 2019-11-21 09:15:00+05:30  747.10  747.10  ...       NaN         no
# 2019-11-21 09:30:00+05:30  743.90  743.90  ...       NaN         no
# 2019-11-21 09:45:00+05:30  740.50  742.15  ...       NaN        buy
# 2019-11-21 10:00:00+05:30  738.25  740.85  ...       NaN       sell
# ...                           ...     ...  ...       ...        ...
# 2020-11-03 15:15:00+05:30  533.85  535.00  ...  0.851163         no
# 2020-11-04 09:15:00+05:30  529.90  531.00  ...  0.924426        buy
# 2020-11-04 09:30:00+05:30  528.35  532.75  ...  0.878446       sell
# 2020-11-04 09:45:00+05:30  533.75  533.75  ...  0.897463         no
# 2020-11-04 10:00:00+05:30  525.00  526.20  ...  1.115152         no
#
# [6000 rows x 197 columns]

# %%
trainp.isnull().sum()
# Out:
# open          0
# high          0
# low           0
# close         0
# volume        0
#              ..
# Z_30         29
# VIDYA_14     14
# VTXP_14      14
# VTXM_14      14
# final_buy     0
# Length: 197, dtype: int64

# %%
trainp
# Out:
# Empty DataFrame
# ...
